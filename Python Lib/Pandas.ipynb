# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('Flights.parquet')

# %%
df.shape
# Out:
# (4078318, 61)

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4078318 entries, 0 to 590541
# Data columns (total 61 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               datetime64[ns]
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   Cancelled                                bool
#  5   Diverted                                 bool
#  6   CRSDepTime                               int64
#  7   DepTime                                  float64
#  8   DepDelayMinutes                          float64
#  9   DepDelay                                 float64
#  10  ArrTime                                  float64
#  11  ArrDelayMinutes                          float64
#  12  AirTime                                  float64
# ...

# %%
#df.to_csv(), df.to_parquet(), df.to_sql() etc

# %%
pd.set_option('display.max_columns', 100)

# %%
df.head()
#df.tail()
#df.sample()
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
# 3      False     False        1435   1430.0              0.0      -5.0
# 4      False     False        1135   1135.0              0.0       0.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.info(verbose=False) #for quick summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4078318 entries, 0 to 590541
# Columns: 61 entries, FlightDate to DivAirportLandings
# dtypes: bool(2), datetime64[ns](1), float64(18), int64(23), object(17)
# memory usage: 1.8+ GB

# %%
df.describe()
# Out:
#          CRSDepTime       DepTime  DepDelayMinutes      DepDelay  \
# count  4.078318e+06  3.957885e+06     3.957823e+06  3.957823e+06
# mean   1.329587e+03  1.334374e+03     1.601494e+01  1.309049e+01
# std    4.904801e+02  5.056219e+02     5.231498e+01  5.332016e+01
# min    1.000000e+00  1.000000e+00     0.000000e+00 -7.800000e+01
# 25%    9.140000e+02  9.170000e+02     0.000000e+00 -5.000000e+00
# 50%    1.320000e+03  1.325000e+03     0.000000e+00 -2.000000e+00
# 75%    1.735000e+03  1.744000e+03     1.100000e+01  1.100000e+01
# max    2.359000e+03  2.400000e+03     7.223000e+03  7.223000e+03
#
#             ArrTime  ArrDelayMinutes       AirTime  CRSElapsedTime  \
# count  3.954079e+06     3.944916e+06  3.944916e+06    4.078318e+06
# mean   1.457886e+03     1.578307e+01  1.110075e+02    1.413211e+02
# std    5.431841e+02     5.198424e+01  6.996246e+01    7.179635e+01
# min    1.000000e+00     0.000000e+00  8.000000e+00   -4.800000e+01
# ...

# %%
df[['Airline']].describe()
# Out:
#                        Airline
# count                  4078318
# unique                      21
# top     Southwest Airlines Co.
# freq                    731925

# %%
df.shape[0]
# Out:
# 4078318

# %% [markdown]
# # Subset a data

# %%
df[['FlightDate', 'Airline', 'Origin']]
# Out:
#        FlightDate                                    Airline Origin
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# ...           ...                                        ...    ...
# 590537 2022-03-31                          Republic Airlines    MSY
# 590538 2022-03-17                          Republic Airlines    CLT
# 590539 2022-03-08                          Republic Airlines    ALB
# 590540 2022-03-25                          Republic Airlines    EWR
# 590541 2022-03-07                          Republic Airlines    EWR
#
# [4078318 rows x 3 columns]

# %%
df[df.columns[-5:]]
# Out:
#         ArrDel15  ArrivalDelayGroups ArrTimeBlk  DistanceGroup  \
# 0            0.0                -2.0  1200-1259              1
# 1            0.0                -1.0  0800-0859              2
# 2            0.0                -1.0  1600-1659              2
# 3            0.0                -2.0  1600-1659              2
# 4            0.0                 0.0  1200-1259              2
# ...          ...                 ...        ...            ...
# 590537       NaN                 NaN  2300-2359              5
# 590538       NaN                 NaN  1900-1959              3
# 590539       1.0                12.0  1800-1859              3
# 590540       NaN                 NaN  2200-2259              2
# 590541       NaN                 NaN  1300-1359              2
#
#         DivAirportLandings
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# ...

# %% [markdown]
# # List comprehension

# %%
[c for c in df.columns if 'Time' in c]
# Out:
# ['CRSDepTime',
#  'DepTime',
#  'ArrTime',
#  'AirTime',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'DepTimeBlk',
#  'CRSArrTime',
#  'ArrTimeBlk']

# %%
df[[c for c in df.columns if 'Time' in c]]
# Out:
#         CRSDepTime  DepTime  ArrTime  AirTime  CRSElapsedTime  \
# 0             1133   1123.0   1228.0     40.0            72.0
# 1              732    728.0    848.0     55.0            77.0
# 2             1529   1514.0   1636.0     47.0            70.0
# 3             1435   1430.0   1547.0     57.0            90.0
# 4             1135   1135.0   1251.0     49.0            70.0
# ...            ...      ...      ...      ...             ...
# 590537        1949   2014.0    234.0      NaN           185.0
# 590538        1733   1817.0      NaN      NaN           129.0
# 590539        1700   2318.0     59.0    135.0           158.0
# 590540        2129   2322.0    939.0      NaN            86.0
# 590541        1154   1148.0   1556.0      NaN            99.0
#
#         ActualElapsedTime DepTimeBlk  CRSArrTime ArrTimeBlk
# 0                    65.0  1100-1159        1245  1200-1259
# 1                    80.0  0700-0759         849  0800-0859
# ...

# %%
df.select_dtypes('int')
# Out:
#         CRSDepTime  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0             1133  2022        2      4           4          1
# 1              732  2022        2      4           4          1
# 2             1529  2022        2      4           4          1
# 3             1435  2022        2      4           4          1
# 4             1135  2022        2      4           4          1
# ...            ...   ...      ...    ...         ...        ...
# 590537        1949  2022        1      3          31          4
# 590538        1733  2022        1      3          17          4
# 590539        1700  2022        1      3           8          2
# 590540        2129  2022        1      3          25          5
# 590541        1154  2022        1      3           7          1
#
#         DOT_ID_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                          19977                             4301
# ...

# %%
#df['Airline'] - provide the series instead of dataframe
#df[['Airline']] - provide in dataframe format

# %% [markdown]
# # Filtering Row
#
# - df.loc[ ] - using name
# - df.iloc[ ] - using index location

# %%
df.iloc[0,3] #0 row and 3 columns
# Out:
# 'DEN'

# %%
df.iloc[:5,:5]
# Out:
#   FlightDate                                    Airline Origin Dest  Cancelled
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN      False
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH      False
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT      False
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False

# %%
# df.iloc[5] # provide the series
df.iloc[[5]]
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 5 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DEN  TUL
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 5      False     False         955    952.0              0.0      -3.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 5   1238.0              0.0     77.0           105.0              106.0
#
#    Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 5     541.0  2022        2      4           4          1
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 5                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 5                     19977                          UA
#
#    Flight_Number_Marketing_Airline Operating_Airline  \
# 5                             4294                C5
#
# ...

# %%
df.iloc[:, [1]]
# Out:
#                                           Airline
# 0       Commutair Aka Champlain Enterprises, Inc.
# 1       Commutair Aka Champlain Enterprises, Inc.
# 2       Commutair Aka Champlain Enterprises, Inc.
# 3       Commutair Aka Champlain Enterprises, Inc.
# 4       Commutair Aka Champlain Enterprises, Inc.
# ...                                           ...
# 590537                          Republic Airlines
# 590538                          Republic Airlines
# 590539                          Republic Airlines
# 590540                          Republic Airlines
# 590541                          Republic Airlines
#
# [4078318 rows x 1 columns]

# %%
df.loc[:, ['Airline']]
# Out:
#                                           Airline
# 0       Commutair Aka Champlain Enterprises, Inc.
# 1       Commutair Aka Champlain Enterprises, Inc.
# 2       Commutair Aka Champlain Enterprises, Inc.
# 3       Commutair Aka Champlain Enterprises, Inc.
# 4       Commutair Aka Champlain Enterprises, Inc.
# ...                                           ...
# 590537                          Republic Airlines
# 590538                          Republic Airlines
# 590539                          Republic Airlines
# 590540                          Republic Airlines
# 590541                          Republic Airlines
#
# [4078318 rows x 1 columns]

# %%
#Boolean Expresion in loc
df[df.loc[:, 'Airline'] == 'Spirit Air Lines'].shape, df.shape
# Out:
# ((129208, 61), (4078318, 61))

# %%
df.loc[df.loc[:, 'Airline'] == 'Spirit Air Lines']
# Out:
#        FlightDate           Airline Origin Dest  Cancelled  Diverted  \
# 407040 2022-04-01  Spirit Air Lines    FLL  ORD       True     False
# 407041 2022-04-02  Spirit Air Lines    FLL  ORD       True     False
# 407042 2022-04-03  Spirit Air Lines    FLL  ORD      False     False
# 407043 2022-04-04  Spirit Air Lines    FLL  ORD      False     False
# 407044 2022-04-05  Spirit Air Lines    FLL  ORD      False     False
# ...           ...               ...    ...  ...        ...       ...
# 142478 2022-03-27  Spirit Air Lines    EWR  LAS      False     False
# 142479 2022-03-28  Spirit Air Lines    EWR  LAS      False     False
# 142480 2022-03-29  Spirit Air Lines    EWR  LAS      False     False
# 142481 2022-03-30  Spirit Air Lines    EWR  LAS      False     False
# 142482 2022-03-31  Spirit Air Lines    EWR  LAS       True     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 407040        2025      NaN              NaN       NaN      NaN
# ...

# %%
#filtering based on multiple condition
df.loc[(df.loc[:, 'Airline'] == 'Spirit Air Lines')
       & (df.loc[:, 'FlightDate'] == '2022-01-01')]
# Out:
#        FlightDate           Airline Origin Dest  Cancelled  Diverted  \
# 113924 2022-01-01  Spirit Air Lines    FLL  ORD      False     False
# 113955 2022-01-01  Spirit Air Lines    ORD  FLL      False     False
# 113986 2022-01-01  Spirit Air Lines    ORD  FLL      False     False
# 114010 2022-01-01  Spirit Air Lines    FLL  ORD      False     False
# 114034 2022-01-01  Spirit Air Lines    ATL  MSP      False     False
# ...           ...               ...    ...  ...        ...       ...
# 131334 2022-01-01  Spirit Air Lines    CLT  FLL      False     False
# 131365 2022-01-01  Spirit Air Lines    FLL  CLT      False     False
# 131396 2022-01-01  Spirit Air Lines    DTW  MSY      False     False
# 131418 2022-01-01  Spirit Air Lines    MSY  ORD      False     False
# 131447 2022-01-01  Spirit Air Lines    EWR  LAS       True     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 113924        2240   2254.0             14.0      14.0     56.0
# ...

# %%
#filtering based on inverse multiple condition
df.loc[~((df.loc[:, 'Airline'] == 'Spirit Air Lines')
       & (df.loc[:, 'FlightDate'] == '2022-01-01'))].shape, df.shape
# Out:
# ((4077665, 61), (4078318, 61))

# %% [markdown]
# # Filtering using query method

# %%
#string representation of the boolean expression
min_time = 1130
df.query('(DepTime > @min_time) and (Origin == "DRO")')
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 531    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 533    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 1003   2022-04-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 445339 2022-03-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445977 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445986 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446617 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446626 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %% [markdown]
# # Summarizing the data in dataframe

# %%
df['DepTime'].min(), df['DepTime'].max(), df['DepTime'].std(), df['DepTime'].mean(), \
    df['DepTime'].var(), df['DepTime'].count(), df['DepTime'].sum(), df['DepTime'].quantile([0.25, 0.75])
# Out:
# (1.0,
#  2400.0,
#  505.62193314196895,
#  1334.3739312789533,
#  255653.53927422172,
#  3957885,
#  5281298567.0,
#  0.25     917.0
#  0.75    1744.0
#  Name: DepTime, dtype: float64)

# %%
#df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].min() #this gives string with column as index
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['min', 'max', 'mean'])
# Out:
#           DepTime     DepDelay      ArrTime     ArrDelay
# min      1.000000   -78.000000     1.000000  -100.000000
# max   2400.000000  7223.000000  2400.000000  7232.000000
# mean  1334.373931    13.090487  1457.886018     7.528486

# %%
#agg method can also takes dict as input
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(
    {'DepTime' : ['min', 'max'],
     'DepDelay' : ['mean'],
     'ArrTime' : ['min', 'std']
})
# Out:
#       DepTime   DepDelay     ArrTime
# min       1.0        NaN    1.000000
# max    2400.0        NaN         NaN
# mean      NaN  13.090487         NaN
# std       NaN        NaN  543.184106

# %%
df['Airline'].unique(), df['Airline'].nunique()
# Out:
# (array(['Commutair Aka Champlain Enterprises, Inc.',
#         'GoJet Airlines, LLC d/b/a United Express',
#         'Air Wisconsin Airlines Corp', 'Mesa Airlines Inc.',
#         'Southwest Airlines Co.', 'Republic Airlines', 'Endeavor Air Inc.',
#         'American Airlines Inc.', 'Capital Cargo International',
#         'SkyWest Airlines Inc.', 'Alaska Airlines Inc.', 'JetBlue Airways',
#         'Delta Air Lines Inc.', 'Frontier Airlines Inc.', 'Allegiant Air',
#         'Hawaiian Airlines Inc.', 'Envoy Air', 'Spirit Air Lines',
#         'Comair Inc.', 'Horizon Air', 'United Air Lines Inc.'],
#        dtype=object),
#  21)

# %%
df['Airline'].value_counts(normalize=True) #[['Airline', 'Origin']]
# Out:
# Southwest Airlines Co.                       0.179467
# Delta Air Lines Inc.                         0.125570
# American Airlines Inc.                       0.121607
# SkyWest Airlines Inc.                        0.108085
# United Air Lines Inc.                        0.086312
# Republic Airlines                            0.048520
# JetBlue Airways                              0.038446
# Envoy Air                                    0.036966
# Endeavor Air Inc.                            0.034971
# Comair Inc.                                  0.033319
# Alaska Airlines Inc.                         0.031756
# Spirit Air Lines                             0.031682
# Frontier Airlines Inc.                       0.021224
# Allegiant Air                                0.018023
# Mesa Airlines Inc.                           0.017647
# Horizon Air                                  0.013810
# Capital Cargo International                  0.012953
# ...

# %%
df[['Airline', 'Origin']].value_counts().reset_index()
# Out:
#                                         Airline Origin       0
# 0                          Delta Air Lines Inc.    ATL  120919
# 1                        American Airlines Inc.    DFW   81239
# 2                        American Airlines Inc.    CLT   57914
# 3                         United Air Lines Inc.    DEN   46489
# 4                        Southwest Airlines Co.    DEN   45398
# ...                                         ...    ...     ...
# 2189                     Frontier Airlines Inc.    ICT       1
# 2190                         Mesa Airlines Inc.    MDT       1
# 2191                Air Wisconsin Airlines Corp    FWA       1
# 2192  Commutair Aka Champlain Enterprises, Inc.    DSM       1
# 2193   GoJet Airlines, LLC d/b/a United Express    MKE       1
#
# [2194 rows x 3 columns]

# %% [markdown]
# # Advanced column method

# %%
#rank based on numerical data value based on the max column
df[['CRSDepTime']].rank(method = 'dense')
# Out:
#         CRSDepTime
# 0            574.0
# 1            333.0
# 2            810.0
# 3            756.0
# 4            576.0
# ...            ...
# 590537      1070.0
# 590538       934.0
# 590539       901.0
# 590540      1170.0
# 590541       595.0
#
# [4078318 rows x 1 columns]

# %%
test = pd.DataFrame ( [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'Los Angeles'],
    ['Charlie', 35, 'Chicago'],
    ['D', 35, 'Do'],
    ['F', 15, 'Fo'],
], columns= ['Name', 'Age', 'City'])

# %%
test['Age'].rank(method = 'dense')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# Name: Age, dtype: float64

# %%
test['Age'].shift(1, fill_value=0)
# Out:
# 0     0
# 1    25
# 2    30
# 3    35
# Name: Age, dtype: int64

# %%
test['Age'].rank(method = 'first')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: Age, dtype: float64

# %%
#cumulative sum
test['Age'].cumsum()
# Out:
# 0     25
# 1     55
# 2     90
# 3    125
# 4    140
# Name: Age, dtype: int64

# %%
test['Age'].cummax()
# Out:
# 0    25
# 1    30
# 2    35
# 3    35
# 4    35
# Name: Age, dtype: int64

# %%
test['Age'].cummin()
# Out:
# 0    25
# 1    25
# 2    25
# 3    25
# 4    15
# Name: Age, dtype: int64

# %% [markdown]
# # Rolling methods

# %%
df[['DepDelayMinutes']].rolling(window = 5).mean()
# Out:
#         DepDelayMinutes
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   0.0
# ...                 ...
# 590537            144.2
# 590538            108.4
# 590539            145.0
# 590540            142.8
# 590541            112.0
#
# [4078318 rows x 1 columns]

# %%
df['DepTime'].clip(1000, 2000)
# Out:
# 0         1123.0
# 1         1000.0
# 2         1514.0
# 3         1430.0
# 4         1135.0
#            ...
# 590537    2000.0
# 590538    1817.0
# 590539    2000.0
# 590540    2000.0
# 590541    1148.0
# Name: DepTime, Length: 4078318, dtype: float64

# %% [markdown]
# # GroupBy Method

# %%
df.groupby('Airline')[['DepDelay']].mean()
df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['min', 'max', 'mean']) #Multi indexed columns
# Out:
#                                           DepDelay                     \
#                                                min     max       mean
# Airline
# Air Wisconsin Airlines Corp                  -30.0  1355.0   7.913244
# Alaska Airlines Inc.                         -63.0   915.0   5.925950
# Allegiant Air                                -37.0  1917.0  19.061569
# American Airlines Inc.                       -35.0  2994.0  14.876556
# Capital Cargo International                  -34.0  1512.0   6.044430
# Comair Inc.                                  -49.0  1607.0  12.693968
# Commutair Aka Champlain Enterprises, Inc.    -27.0  1464.0  12.093640
# Delta Air Lines Inc.                         -38.0  1287.0  11.398599
# Endeavor Air Inc.                            -34.0  1973.0   9.696390
# Envoy Air                                    -29.0  5327.0   6.883448
# Frontier Airlines Inc.                       -40.0  1288.0  20.052761
# ...

# %%
df2 = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['min', 'max', 'mean'])

# %%
df2.columns
# Out:
# MultiIndex([('DepDelay',  'min'),
#             ('DepDelay',  'max'),
#             ('DepDelay', 'mean'),
#             ('ArrDelay',  'min'),
#             ('ArrDelay',  'max'),
#             ('ArrDelay', 'mean')],
#            )

# %%
df2.columns.to_flat_index() #list of tuple
# Out:
# Index([ ('DepDelay', 'min'),  ('DepDelay', 'max'), ('DepDelay', 'mean'),
#         ('ArrDelay', 'min'),  ('ArrDelay', 'max'), ('ArrDelay', 'mean')],
#       dtype='object')

# %%
df2.columns = ['_'.join(c) for c in df2.columns]

# %%
df2.head(2)
# Out:
#                              DepDelay_min  DepDelay_max  DepDelay_mean  \
# Airline
# Air Wisconsin Airlines Corp         -30.0        1355.0       7.913244
# Alaska Airlines Inc.                -63.0         915.0       5.925950
#
#                              ArrDelay_min  ArrDelay_max  ArrDelay_mean
# Airline
# Air Wisconsin Airlines Corp         -63.0        1353.0       1.819183
# Alaska Airlines Inc.                -76.0         908.0       3.170588

# %% [markdown]
# # New Columns

# %%
df['DepTime2'] = df['DepTime'] / 60

# %%
df = df.assign(DepTime3 = df['DepTime'] / 2)
df.head(2)
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 0   1228.0              0.0     40.0            72.0               65.0
# 1    848.0              0.0     55.0            77.0               80.0
#
#    Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0     212.0  2022        2      4           4          1
# 1     295.0  2022        2      4           4          1
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# ...

# %%
df[['FlightDate','Airline','ArrDelay']].sort_values('ArrDelay', ascending = False) \
.reset_index(drop = True)
# Out:
#         FlightDate                 Airline  ArrDelay
# 0       2022-05-23       Republic Airlines    7232.0
# 1       2022-06-18               Envoy Air    5324.0
# 2       2022-05-16       Republic Airlines    4318.0
# 3       2022-06-05  American Airlines Inc.    2977.0
# 4       2022-03-26  American Airlines Inc.    2934.0
# ...            ...                     ...       ...
# 4078313 2022-03-31       Republic Airlines       NaN
# 4078314 2022-03-31       Republic Airlines       NaN
# 4078315 2022-03-17       Republic Airlines       NaN
# 4078316 2022-03-25       Republic Airlines       NaN
# 4078317 2022-03-07       Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %% [markdown]
# # Handling Missing data

# %%
df[['FlightDate','Airline','ArrDelay']].isna().sum()
# Out:
# FlightDate         0
# Airline            0
# ArrDelay      133402
# dtype: int64

# %%
#df[['FlightDate','Airline'su,'ArrDelay']].dropna(subset = 'ArrDelay') Drop only happend when null is in ArrDelay column
df[['FlightDate','Airline','ArrDelay']].fillna(-9999)
# Out:
#        FlightDate                                    Airline  ArrDelay
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...           ...                                        ...       ...
# 590537 2022-03-31                          Republic Airlines   -9999.0
# 590538 2022-03-17                          Republic Airlines   -9999.0
# 590539 2022-03-08                          Republic Airlines     381.0
# 590540 2022-03-25                          Republic Airlines   -9999.0
# 590541 2022-03-07                          Republic Airlines   -9999.0
#
# [4078318 rows x 3 columns]

# %%
df[['ArrDelay']].fillna(df['ArrDelay'].mean())
# Out:
#           ArrDelay
# 0       -17.000000
# 1        -1.000000
# 2        -3.000000
# 3       -18.000000
# 4         6.000000
# ...            ...
# 590537    7.528486
# 590538    7.528486
# 590539  381.000000
# 590540    7.528486
# 590541    7.528486
#
# [4078318 rows x 1 columns]

# %% [markdown]
# # Combining data

# %%
df1 = df.query('Airline == "Southwest Airlines Co."').copy() #to make df2 independent from df
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# %%
df_stack = pd.concat([df1, df2])

df1 = df1.reset_index(drop = True)
df2 = df2.reset_index(drop = True)

df_side = pd.concat([df1, df2], axis = 1)

# %%
df_stack.shape, df1.shape, df2.shape, df_side.shape
# Out:
# ((1244039, 61), (731925, 61), (512114, 61), (731925, 122))

# %% [markdown]
# # Merge data based on similar columns

# %%
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
df1.columns, df2.columns
# Out:
# (Index(['Airline', 'FlightDate', 'DepDelay'], dtype='object'),
#  Index(['Airline', 'FlightDate', 'ArrDelay'], dtype='object'))

# %%
#df1.merge(df2) take similar column from both the data source and combined those
df1.merge(df2, how = 'inner')
# Out:
#                           Airline FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp 2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp 2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp 2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp 2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp 2022-01-05  20.532967  20.250000
# ...                           ...        ...        ...        ...
# 4447        United Air Lines Inc. 2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc. 2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc. 2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc. 2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc. 2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
pd.merge(df1, df2, on = ['Airline', 'FlightDate'])
# Out:
#                           Airline FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp 2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp 2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp 2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp 2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp 2022-01-05  20.532967  20.250000
# ...                           ...        ...        ...        ...
# 4447        United Air Lines Inc. 2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc. 2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc. 2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc. 2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc. 2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
pd.merge(df1, df2, on = ['Airline'])
# Out:
#                             Airline FlightDate_x   DepDelay FlightDate_y  \
# 0       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-01
# 1       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-02
# 2       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-03
# 3       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-04
# 4       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-05
# ...                             ...          ...        ...          ...
# 943819        United Air Lines Inc.   2022-07-31  12.688534   2022-07-27
# 943820        United Air Lines Inc.   2022-07-31  12.688534   2022-07-28
# 943821        United Air Lines Inc.   2022-07-31  12.688534   2022-07-29
# 943822        United Air Lines Inc.   2022-07-31  12.688534   2022-07-30
# 943823        United Air Lines Inc.   2022-07-31  12.688534   2022-07-31
#
#          ArrDelay
# 0        5.717949
# 1       36.641176
# 2       36.525316
# ...

# %%
pd.merge(df1, df2, left_on = ['Airline', 'FlightDate'], right_on = ['Airline', 'FlightDate']) # if the name is different in both the data frame
# Out:
#                           Airline FlightDate   DepDelay   ArrDelay
# 0     Air Wisconsin Airlines Corp 2022-01-01   8.784810   5.717949
# 1     Air Wisconsin Airlines Corp 2022-01-02  41.766082  36.641176
# 2     Air Wisconsin Airlines Corp 2022-01-03  46.183544  36.525316
# 3     Air Wisconsin Airlines Corp 2022-01-04   6.141304  -5.842391
# 4     Air Wisconsin Airlines Corp 2022-01-05  20.532967  20.250000
# ...                           ...        ...        ...        ...
# 4447        United Air Lines Inc. 2022-07-27  12.064677   4.912778
# 4448        United Air Lines Inc. 2022-07-28  14.437948   6.640288
# 4449        United Air Lines Inc. 2022-07-29  11.029185   4.629425
# 4450        United Air Lines Inc. 2022-07-30   6.192961  -4.716889
# 4451        United Air Lines Inc. 2022-07-31  12.688534   4.626857
#
# [4452 rows x 4 columns]

# %%
import pandas as pd

# %%
??pd.merge
